# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
d1=pd.read_csv('/content/drive/MyDrive/2021VAERSData.csv',encoding='ISO-8859-1')
d2=pd.read_csv('/content/drive/MyDrive/2021VAERSSYMPTOMS.csv')
d3=pd.read_csv('/content/drive/MyDrive/2021VAERSVAX.csv',encoding='ISO-8859-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (7,12,15,23) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
d51=d1[['VAERS_ID','DIED']]
d52=d2[['VAERS_ID','SYMPTOM1','SYMPTOM2','SYMPTOM3','SYMPTOM4','SYMPTOM5']]
d53=d3[['VAERS_ID','VAX_TYPE','VAX_MANU']]
dm1=pd.merge(d51,d53,on='VAERS_ID')
dm2=pd.merge(dm1,d52,on='VAERS_ID')
dm2
# Out:
#          VAERS_ID DIED  ...                     SYMPTOM4           SYMPTOM5
# 0          916600  NaN  ...                          NaN                NaN
# 1          916601  NaN  ...                          NaN                NaN
# 2          916602  NaN  ...            Visual impairment                NaN
# 3          916603  NaN  ...                          NaN                NaN
# 4          916604  NaN  ...        Injection site warmth                NaN
# ...           ...  ...  ...                          ...                ...
# 1009762   1919878    Y  ...                          NaN                NaN
# 1009763   1919904  NaN  ...  Ejection fraction decreased  Electrocardiogram
# 1009764   1919904  NaN  ...                          NaN                NaN
# 1009765   1919911    Y  ...                  Hypersomnia       Indifference
# 1009766   1919911    Y  ...                          NaN                NaN
#
# [1009767 rows x 9 columns]

# %%
dm21=dm2.query('VAX_TYPE==["COVID19"]')
dm21
# Out:
#          VAERS_ID DIED  ...                     SYMPTOM4           SYMPTOM5
# 0          916600  NaN  ...                          NaN                NaN
# 1          916601  NaN  ...                          NaN                NaN
# 2          916602  NaN  ...            Visual impairment                NaN
# 3          916603  NaN  ...                          NaN                NaN
# 4          916604  NaN  ...        Injection site warmth                NaN
# ...           ...  ...  ...                          ...                ...
# 1009762   1919878    Y  ...                          NaN                NaN
# 1009763   1919904  NaN  ...  Ejection fraction decreased  Electrocardiogram
# 1009764   1919904  NaN  ...                          NaN                NaN
# 1009765   1919911    Y  ...                  Hypersomnia       Indifference
# 1009766   1919911    Y  ...                          NaN                NaN
#
# [947499 rows x 9 columns]

# %%
dm22=dm21[['VAX_MANU','SYMPTOM1','SYMPTOM2','SYMPTOM3','SYMPTOM4','SYMPTOM5']]
dm22
# Out:
#                 VAX_MANU  ...           SYMPTOM5
# 0                MODERNA  ...                NaN
# 1                MODERNA  ...                NaN
# 2        PFIZER\BIONTECH  ...                NaN
# 3                MODERNA  ...                NaN
# 4                MODERNA  ...                NaN
# ...                  ...  ...                ...
# 1009762          MODERNA  ...                NaN
# 1009763  PFIZER\BIONTECH  ...  Electrocardiogram
# 1009764  PFIZER\BIONTECH  ...                NaN
# 1009765          MODERNA  ...       Indifference
# 1009766          MODERNA  ...                NaN
#
# [947499 rows x 6 columns]

# %%
dm22.VAX_MANU.value_counts()
# Out:
# MODERNA                 431929
# PFIZER\BIONTECH         425998
# JANSSEN                  87454
# UNKNOWN MANUFACTURER      2118
# Name: VAX_MANU, dtype: int64

# %%
dm22m=dm22.query('VAX_MANU==["MODERNA"]')
dm22m
# Out:
#         VAX_MANU  ...                  SYMPTOM5
# 0        MODERNA  ...                       NaN
# 1        MODERNA  ...                       NaN
# 3        MODERNA  ...                       NaN
# 4        MODERNA  ...                       NaN
# 7        MODERNA  ...                       NaN
# ...          ...  ...                       ...
# 1009760  MODERNA  ...  SARS-CoV-2 test positive
# 1009761  MODERNA  ...                       NaN
# 1009762  MODERNA  ...                       NaN
# 1009765  MODERNA  ...              Indifference
# 1009766  MODERNA  ...                       NaN
#
# [431929 rows x 6 columns]

# %%
dm22m1=pd.DataFrame(dm22m.SYMPTOM1.value_counts())
dm22m2=pd.DataFrame(dm22m.SYMPTOM2.value_counts())
dm22m3=pd.DataFrame(dm22m.SYMPTOM3.value_counts())
dm22m4=pd.DataFrame(dm22m.SYMPTOM4.value_counts())
dm22m5=pd.DataFrame(dm22m.SYMPTOM5.value_counts())
dm22mf=dm22m1.join(dm22m2)
dm22mf=dm22mf.join(dm22m3)
dm22mf=dm22mf.join(dm22m4)
dm22mf=dm22mf.join(dm22m5)
dm22mf
# Out:
#                               SYMPTOM1  SYMPTOM2  SYMPTOM3  SYMPTOM4  SYMPTOM5
# Chills                           25522   12408.0    3894.0    1299.0     505.0
# Arthralgia                       17147    1547.0     285.0      46.0       9.0
# Injection site erythema          14677    4066.0    2104.0    1306.0     716.0
# Fatigue                          12228   15518.0   10770.0    5887.0    3227.0
# Dizziness                        11369    8156.0    4438.0    2319.0    1021.0
# ...                                ...       ...       ...       ...       ...
# Reflex test abnormal                 1       NaN       NaN       NaN       1.0
# Eye oedema                           1       2.0       2.0       2.0       NaN
# Multimorbidity                       1       NaN       1.0       NaN       3.0
# Metanephrine urine increased         1       NaN       NaN       NaN       NaN
# Systolic hypertension                1       NaN       NaN       NaN       1.0
#
# [5378 rows x 5 columns]

# %%
dm22mf=dm22mf.fillna(0)
dm22mf['total']=dm22mf['SYMPTOM1']+dm22mf['SYMPTOM2']+dm22mf['SYMPTOM3']+dm22mf['SYMPTOM4']+dm22mf['SYMPTOM5']
dm22mf['ratio']=dm22mf['total']/431929
dm22mf
dm22mff=dm22mf.sort_values(by=['total'],ascending=False)
dm22mfff=pd.DataFrame(dm22mff['total'])
dm22mffff=pd.DataFrame(dm22mff['ratio'])
dmfd1=dm22mfff.join(dm22mffff)
dmfd1
# Out:
#                                           total     ratio
# Headache                                54867.0  0.127028
# Pyrexia                                 50630.0  0.117218
# Fatigue                                 47630.0  0.110273
# Chills                                  43628.0  0.101007
# Pain                                    40237.0  0.093157
# ...                                         ...       ...
# Pituitary scan                              1.0  0.000002
# Body mass index increased                   1.0  0.000002
# Bone anchored hearing aid implantation      1.0  0.000002
# Drug administered in wrong device           1.0  0.000002
# Forced expiratory volume decreased          1.0  0.000002
#
# [5378 rows x 2 columns]

# %%
dmfd1.head(10)
# Out:
#                            total     ratio
# Headache                 54867.0  0.127028
# Pyrexia                  50630.0  0.117218
# Fatigue                  47630.0  0.110273
# Chills                   43628.0  0.101007
# Pain                     40237.0  0.093157
# Pain in extremity        33592.0  0.077772
# Nausea                   30850.0  0.071424
# Dizziness                27303.0  0.063212
# Injection site pain      23214.0  0.053745
# Injection site erythema  22869.0  0.052946

# %%
data = [
    plotly.graph_objs.Bar(x=dmfd1.index[0:30], y=dmfd1['total'][0:30], name='症状'),
]
layout = plotly.graph_objs.Layout(
    title='症状のグラフ',
    xaxis={'title':'症状（英語）'}, 
    yaxis={'title':'数', 'rangemode':'tozero'},
)
fig = plotly.graph_objs.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c812162a-8fe7-435c-83aa-c2b83dadf565" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c812162a-8fe7-435c-83aa-c2b83dadf565")) {
#                     Plotly.newPlot(
#                         'c812162a-8fe7-435c-83aa-c2b83dadf565',
#                         [{"name": "\u75c7\u72b6", "type": "bar", "x": ["Headache", "Pyrexia", "Fatigue", "Chills", "Pain", "Pain in extremity", "Nausea", "Dizziness", "Injection site pain", "Injection site erythema", "Myalgia", "Arthralgia", "Rash", "Pruritus", "Injection site swelling", "Injection site pruritus", "Dyspnoea", "Erythema", "Asthenia", "Vomiting", "Injection site warmth", "COVID-19", "Diarrhoea", "Peripheral swelling", "Feeling abnormal", "Urticaria", "Injection site rash", "SARS-CoV-2 test positive", "Hyperhidrosis", "Vaccination site pain"], "y": [54867.0, 50630.0, 47630.0, 43628.0, 40237.0, 33592.0, 30850.0, 27303.0, 23214.0, 22869.0, 21917.0, 19034.0, 18796.0, 18472.0, 17861.0, 16719.0, 16020.0, 14752.0, 13215.0, 12243.0, 12024.0, 11335.0, 10470.0, 10004.0, 9997.0, 9820.0, 9494.0, 8755.0, 8738.0, 8726.0]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
dm22m=dm22.query('VAX_MANU==["PFIZER\BIONTECH"]')
dm22m
# Out:
#                 VAX_MANU  ...                  SYMPTOM5
# 2        PFIZER\BIONTECH  ...                       NaN
# 25       PFIZER\BIONTECH  ...                   Pyrexia
# 27       PFIZER\BIONTECH  ...                       NaN
# 33       PFIZER\BIONTECH  ...                       NaN
# 35       PFIZER\BIONTECH  ...               Tachycardia
# ...                  ...  ...                       ...
# 1009705  PFIZER\BIONTECH  ...  Irritable bowel syndrome
# 1009706  PFIZER\BIONTECH  ...                       NaN
# 1009707  PFIZER\BIONTECH  ...                    Nausea
# 1009763  PFIZER\BIONTECH  ...         Electrocardiogram
# 1009764  PFIZER\BIONTECH  ...                       NaN
#
# [425998 rows x 6 columns]

# %%
dm22m1=pd.DataFrame(dm22m.SYMPTOM1.value_counts())
dm22m2=pd.DataFrame(dm22m.SYMPTOM2.value_counts())
dm22m3=pd.DataFrame(dm22m.SYMPTOM3.value_counts())
dm22m4=pd.DataFrame(dm22m.SYMPTOM4.value_counts())
dm22m5=pd.DataFrame(dm22m.SYMPTOM5.value_counts())
dm22mf=dm22m1.join(dm22m2)
dm22mf=dm22mf.join(dm22m3)
dm22mf=dm22mf.join(dm22m4)
dm22mf=dm22mf.join(dm22m5)
dm22mf
# Out:
#                               SYMPTOM1  SYMPTOM2  SYMPTOM3  SYMPTOM4  SYMPTOM5
# Chills                           17948   10381.0    3783.0    1527.0     555.0
# Arthralgia                       16898    1650.0     329.0      76.0      25.0
# Dizziness                        15814    9282.0    4915.0    2539.0    1267.0
# COVID-19                         15231    2490.0    1395.0     482.0     270.0
# Fatigue                          11059   13937.0   10194.0    5899.0    3393.0
# ...                                ...       ...       ...       ...       ...
# Mean platelet volume                 1       1.0       4.0       3.0       3.0
# Mucosal inflammation                 1       1.0       3.0       2.0       3.0
# Loss of therapeutic response         1       1.0       NaN       NaN       NaN
# Reticulocyte count normal            1       NaN       1.0       3.0       NaN
# Urine osmolarity                     1       1.0       1.0       NaN       NaN
#
# [5666 rows x 5 columns]

# %%
dm22mf=dm22mf.fillna(0)
dm22mf['total']=dm22mf['SYMPTOM1']+dm22mf['SYMPTOM2']+dm22mf['SYMPTOM3']+dm22mf['SYMPTOM4']+dm22mf['SYMPTOM5']
dm22mf['ratio']=dm22mf['total']/425998
dm22mf
dm22mff=dm22mf.sort_values(by=['total'],ascending=False)
dm22mfff=pd.DataFrame(dm22mff['total'])
dm22mffff=pd.DataFrame(dm22mff['ratio'])
dmfd1=dm22mfff.join(dm22mffff)
dmfd1
# Out:
#                                total     ratio
# Headache                     51824.0  0.121653
# Fatigue                      44482.0  0.104418
# Pyrexia                      40677.0  0.095486
# Pain                         37314.0  0.087592
# Chills                       34194.0  0.080268
# ...                              ...       ...
# Autonomic dysreflexia            1.0  0.000002
# Gingival erosion                 1.0  0.000002
# Enterococcal sepsis              1.0  0.000002
# Allergy to surgical sutures      1.0  0.000002
# Scrotal exploration              1.0  0.000002
#
# [5666 rows x 2 columns]

# %%
dmfd1.head(10)
# Out:
#                      total     ratio
# Headache           51824.0  0.121653
# Fatigue            44482.0  0.104418
# Pyrexia            40677.0  0.095486
# Pain               37314.0  0.087592
# Chills             34194.0  0.080268
# Dizziness          33817.0  0.079383
# Nausea             30111.0  0.070683
# Pain in extremity  26692.0  0.062658
# Dyspnoea           20188.0  0.047390
# COVID-19           19868.0  0.046639

# %%
data = [
    plotly.graph_objs.Bar(x=dmfd1.index[0:30], y=dmfd1['total'][0:30], name='症状'),
]
layout = plotly.graph_objs.Layout(
    title='症状のグラフ',
    xaxis={'title':'症状（英語）'}, 
    yaxis={'title':'数', 'rangemode':'tozero'},
)
fig = plotly.graph_objs.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="318009f9-d6ed-4c86-a49f-a5f78c5ab3db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("318009f9-d6ed-4c86-a49f-a5f78c5ab3db")) {
#                     Plotly.newPlot(
#                         '318009f9-d6ed-4c86-a49f-a5f78c5ab3db',
#                         [{"name": "\u75c7\u72b6", "type": "bar", "x": ["Headache", "Fatigue", "Pyrexia", "Pain", "Chills", "Dizziness", "Nausea", "Pain in extremity", "Dyspnoea", "COVID-19", "Arthralgia", "Myalgia", "Rash", "SARS-CoV-2 test positive", "Pruritus", "Asthenia", "Vomiting", "Chest pain", "Paraesthesia", "Injection site pain", "Lymphadenopathy", "Cough", "Hypoaesthesia", "Diarrhoea", "SARS-CoV-2 test", "Malaise", "Hyperhidrosis", "Feeling abnormal", "Urticaria", "Blood test"], "y": [51824.0, 44482.0, 40677.0, 37314.0, 34194.0, 33817.0, 30111.0, 26692.0, 20188.0, 19868.0, 18978.0, 16188.0, 15295.0, 15235.0, 12784.0, 12379.0, 12262.0, 11790.0, 11598.0, 11497.0, 11294.0, 11226.0, 11055.0, 10846.0, 10348.0, 10048.0, 9775.0, 9693.0, 9091.0, 8014.0]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
dm22m=dm22.query('VAX_MANU==["JANSSEN"]')
dm22m
# Out:
#         VAX_MANU  ...               SYMPTOM5
# 178961   JANSSEN  ...                    NaN
# 181734   JANSSEN  ...                    NaN
# 181836   JANSSEN  ...          Hyperhidrosis
# 181837   JANSSEN  ...  Loss of consciousness
# 181838   JANSSEN  ...         Vision blurred
# ...          ...  ...                    ...
# 1009719  JANSSEN  ...                    NaN
# 1009720  JANSSEN  ...           Sensory loss
# 1009721  JANSSEN  ...               Headache
# 1009722  JANSSEN  ...             Renal pain
# 1009723  JANSSEN  ...                    NaN
#
# [87454 rows x 6 columns]

# %%
dm22m1=pd.DataFrame(dm22m.SYMPTOM1.value_counts())
dm22m2=pd.DataFrame(dm22m.SYMPTOM2.value_counts())
dm22m3=pd.DataFrame(dm22m.SYMPTOM3.value_counts())
dm22m4=pd.DataFrame(dm22m.SYMPTOM4.value_counts())
dm22m5=pd.DataFrame(dm22m.SYMPTOM5.value_counts())
dm22mf=dm22m1.join(dm22m2)
dm22mf=dm22mf.join(dm22m3)
dm22mf=dm22mf.join(dm22m4)
dm22mf=dm22mf.join(dm22m5)
dm22mf
# Out:
#                                SYMPTOM1  SYMPTOM2  SYMPTOM3  SYMPTOM4  SYMPTOM5
# Chills                             6524    3053.0    1085.0     376.0     150.0
# Dizziness                          3565    2313.0    1349.0     683.0     356.0
# Arthralgia                         3142     370.0      70.0      14.0       5.0
# Headache                           2957    4472.0    3881.0    2597.0    1646.0
# Fatigue                            2554    3493.0    2429.0    1433.0     742.0
# ...                                 ...       ...       ...       ...       ...
# Arachnoid web                         1       NaN       NaN       NaN       NaN
# Bronchial secretion retention         1       1.0       2.0       NaN       NaN
# Hypertrophic cardiomyopathy           1       NaN       NaN       1.0       NaN
# Oral mucosal discolouration           1       NaN       1.0       NaN       NaN
# Intestinal resection                  1       NaN       NaN       NaN       NaN
#
# [3102 rows x 5 columns]

# %%
dm22mf=dm22mf.fillna(0)
dm22mf['total']=dm22mf['SYMPTOM1']+dm22mf['SYMPTOM2']+dm22mf['SYMPTOM3']+dm22mf['SYMPTOM4']+dm22mf['SYMPTOM5']
dm22mf['ratio']=dm22mf['total']/87454
dm22mf
dm22mff=dm22mf.sort_values(by=['total'],ascending=False)
dm22mfff=pd.DataFrame(dm22mff['total'])
dm22mffff=pd.DataFrame(dm22mff['ratio'])
dmfd1=dm22mfff.join(dm22mffff)
dmfd1
# Out:
#                           total     ratio
# Headache                15553.0  0.177842
# Pyrexia                 13087.0  0.149644
# Chills                  11188.0  0.127930
# Fatigue                 10651.0  0.121790
# Pain                    10640.0  0.121664
# ...                         ...       ...
# pH body fluid abnormal      1.0  0.000011
# Thoracic operation          1.0  0.000011
# Normochromic anaemia        1.0  0.000011
# Penile erythema             1.0  0.000011
# Intestinal resection        1.0  0.000011
#
# [3102 rows x 2 columns]

# %%
dmfd1.head(10)
# Out:
#                      total     ratio
# Headache           15553.0  0.177842
# Pyrexia            13087.0  0.149644
# Chills             11188.0  0.127930
# Fatigue            10651.0  0.121790
# Pain               10640.0  0.121664
# Dizziness           8266.0  0.094518
# Nausea              7970.0  0.091134
# Pain in extremity   6187.0  0.070746
# Myalgia             4142.0  0.047362
# Dyspnoea            4077.0  0.046619
